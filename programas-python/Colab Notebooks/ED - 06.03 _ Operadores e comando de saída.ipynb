# %% [markdown]
# **Conceito básicos: Python**

# %%
#comentário Python

# %% [markdown]
# **COMANDO DE SAÍDA**

# %%
print("Beca")
print('linda')
print(2000) #número não precisa de aspas para imprimir
print(2000+7000) #soma de números
print("Resultado =",458+658) #contatenação "," - int + str
print("Resultado = " + "1116") #contatenação "+" - str + str

# %% [markdown]
# **OPERADORES** **ARTIMÉTICOS**\
# divisão normal "/"\
# divisão inteira "//"\
# exponenciação "**"

# %%
print("divisão normal =",1500/2.3)
print("divisão inteira =",1500//2.3)
print("resto = ", 1500%2.3)
print("exponenciação = ",2**5)
# Out:
# divisão normal = 652.1739130434784
# divisão inteira = 652.0
# resto =  0.4000000000001158
# exponenciação =  32

# %% [markdown]
# **OPERADORES RELACIONAIS**

# %%
print(5>4)
print(4<2)
print(5>=6)
print(5==5)
print(5!=4)
# Out:
# True
# False
# False
# True
# True
