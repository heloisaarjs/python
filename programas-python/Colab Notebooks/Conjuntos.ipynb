# %%
cj =set({1,2,3})
print(type(cj))
print(cj)
# Out:
# <class 'set'>
# {1, 2, 3}

# %%
cj =set({'Amarelo', 'Azul', 'Verde'})
print(type(cj))
print(cj)
# Out:
# <class 'set'>
# {'Azul', 'Amarelo', 'Verde'}

# %%
frutasVermelhas={'Morango','Acerola',  'Melancia'}
frutasAmarelas={'Manga', 'Pêssego','Maracuja','Acerola'}
#uniao
frutas= frutasVermelhas | frutasAmarelas
print(frutas)
#ou
frutas = frutasVermelhas.union(frutasAmarelas)
print(frutas)
#intersecção
frutas = frutasVermelhas & frutasAmarelas
print(frutas)
#ou
frutas = frutasVermelhas.intersection(frutasAmarelas)
print (frutas)
#tamanho
print(f"Total elementos:")
# Out:
# {'Maracuja', 'Pêssego', 'Manga', 'Acerola', 'Morango', 'Melancia'}
# {'Maracuja', 'Pêssego', 'Manga', 'Acerola', 'Morango', 'Melancia'}
# {'Acerola'}
# {'Acerola'}
